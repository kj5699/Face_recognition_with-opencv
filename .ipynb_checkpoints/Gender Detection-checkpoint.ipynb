# %%
import torch
import numpy as np
from torch import nn
from torch import optim
import os
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn.functional as F
from torchvision import datasets ,transforms, models
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from torch.autograd import Variable

# %%
data_dir='gender_data/Training'

def load_split_train_test(data_dir,transform,valid_size=0.2):
    train_data=datasets.ImageFolder(data_dir,transform=transform)
    test_data=datasets.ImageFolder(data_dir,transform=transform)
    
    num_train=len(train_data)
    indices=list(range(num_train))
    split=int(np.floor(valid_size*num_train))
    np.random.shuffle(indices)

    train_idx,test_idx=indices[split:],indices[:split]
    train_sampler=SubsetRandomSampler(train_idx)
    test_sampler=SubsetRandomSampler(test_idx)
    
    trainloader=torch.utils.data.DataLoader(train_data,sampler=train_sampler,batch_size=64)
    testloader=torch.utils.data.DataLoader(train_data,sampler=train_sampler,batch_size=64)
    
    return trainloader,testloader

# %%
transform=transforms.Compose([transforms.Resize((80,80)),transforms.ToTensor(),])

# %%
trainloader,testloader=load_split_train_test(data_dir,transform,.2)

print(trainloader.dataset.classes)

#for batch_images, targets in trainloader:
#print(batch_images.shape)
# Out:
# ['female', 'male']

# %%
# check if gpu is present or not 
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model= models.resnet50(pretrained=True)
print(model)
# Out:
# cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
    param.requires_grad=False

# %%
model.fc=nn.Sequential(nn.Linear(2048,512),
                       nn.ReLU(),
                       nn.Dropout(0.2),
                       nn.Linear(512,10),
                       nn.LogSoftmax(dim=1))
model.to(device)
criterion=nn.NLLLoss()
optimizer=optim.Adam(model.fc.parameters(),lr=0.03)

# %%
epochs=20
steps=0

running_loss=0

print_every=50

train_losses,test_losses=[],[]

for epoch in range(epochs):
    for inputs,labels in trainloader:
        steps+=1
        inputs,labels=inputs.to(device),labels.to(device)
        optimizer.zero_grad()
        logps=model.forward(inputs)
        loss=criterion(logps,labels)
        loss.backward()
        optimizer.step()
        running_loss+=loss.item()
        
        if steps%print_every==0:
            test_loss=0
            accuracy=0
            for inputs,labels in testloader:
                inputs,labels=inputs.to(device),labels.to(device)
                logps=model.forward(inputs)
                batch_loss=criterion(logps,labels)
                test_loss += batch_loss.item()
                ps=torch.exp(logps)
                
                top_p,top_class=ps.topk(1,dim=1)
                equals= top_class==labels.view(*top_class.shape)
                accuracy+=torch.mean(equals.type(torch.FloatTensor)).item()
            train_losses.append(running_loss/print_every)
            test_losses.append(test_loss/len(testloader))
            
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            running_loss=0
            model.train()
            
            
torch.save(model,'classifymodel.pth')
# Out:
# Epoch 1/20.. Train loss: 0.783.. Test loss: 0.392.. Test accuracy: 0.826
# Epoch 1/20.. Train loss: 0.423.. Test loss: 0.356.. Test accuracy: 0.842
# Epoch 1/20.. Train loss: 0.367.. Test loss: 0.341.. Test accuracy: 0.854
# Epoch 1/20.. Train loss: 0.412.. Test loss: 0.335.. Test accuracy: 0.857
# Epoch 1/20.. Train loss: 0.364.. Test loss: 0.345.. Test accuracy: 0.852
# Epoch 2/20.. Train loss: 0.391.. Test loss: 0.349.. Test accuracy: 0.849
# Epoch 2/20.. Train loss: 0.348.. Test loss: 0.344.. Test accuracy: 0.848
# Epoch 2/20.. Train loss: 0.373.. Test loss: 0.376.. Test accuracy: 0.834
# Epoch 2/20.. Train loss: 0.334.. Test loss: 0.320.. Test accuracy: 0.863
# Epoch 2/20.. Train loss: 0.344.. Test loss: 0.317.. Test accuracy: 0.867
# Epoch 3/20.. Train loss: 0.321.. Test loss: 0.329.. Test accuracy: 0.858
# Epoch 3/20.. Train loss: 0.318.. Test loss: 0.313.. Test accuracy: 0.863
# Epoch 3/20.. Train loss: 0.362.. Test loss: 0.416.. Test accuracy: 0.801
# Epoch 3/20.. Train loss: 0.332.. Test loss: 0.331.. Test accuracy: 0.857
# Epoch 3/20.. Train loss: 0.320.. Test loss: 0.336.. Test accuracy: 0.851
# Epoch 4/20.. Train loss: 0.353.. Test loss: 0.309.. Test accuracy: 0.869
# Epoch 4/20.. Train loss: 0.323.. Test loss: 0.302.. Test accuracy: 0.870
# Epoch 4/20.. Train loss: 0.326.. Test loss: 0.293.. Test accuracy: 0.876
# Epoch 4/20.. Train loss: 0.331.. Test loss: 0.325.. Test accuracy: 0.859
# Epoch 4/20.. Train loss: 0.304.. Test loss: 0.323.. Test accuracy: 0.861
# Epoch 5/20.. Train loss: 0.322.. Test loss: 0.308.. Test accuracy: 0.865
# Epoch 5/20.. Train loss: 0.307.. Test loss: 0.302.. Test accuracy: 0.871
# Epoch 5/20.. Train loss: 0.311.. Test loss: 0.293.. Test accuracy: 0.876
# Epoch 5/20.. Train loss: 0.330.. Test loss: 0.287.. Test accuracy: 0.878
# Epoch 5/20.. Train loss: 0.328.. Test loss: 0.286.. Test accuracy: 0.881
# Epoch 6/20.. Train loss: 0.321.. Test loss: 0.306.. Test accuracy: 0.866
# Epoch 6/20.. Train loss: 0.289.. Test loss: 0.284.. Test accuracy: 0.879
# Epoch 6/20.. Train loss: 0.300.. Test loss: 0.294.. Test accuracy: 0.875
# Epoch 6/20.. Train loss: 0.318.. Test loss: 0.277.. Test accuracy: 0.881
# Epoch 6/20.. Train loss: 0.300.. Test loss: 0.284.. Test accuracy: 0.883
# Epoch 7/20.. Train loss: 0.302.. Test loss: 0.280.. Test accuracy: 0.879
# Epoch 7/20.. Train loss: 0.299.. Test loss: 0.295.. Test accuracy: 0.877
# Epoch 7/20.. Train loss: 0.307.. Test loss: 0.291.. Test accuracy: 0.877
# Epoch 7/20.. Train loss: 0.309.. Test loss: 0.278.. Test accuracy: 0.883
# Epoch 7/20.. Train loss: 0.296.. Test loss: 0.287.. Test accuracy: 0.876
# Epoch 7/20.. Train loss: 0.302.. Test loss: 0.269.. Test accuracy: 0.884
# Epoch 8/20.. Train loss: 0.292.. Test loss: 0.281.. Test accuracy: 0.885
# Epoch 8/20.. Train loss: 0.279.. Test loss: 0.277.. Test accuracy: 0.879
# Epoch 8/20.. Train loss: 0.270.. Test loss: 0.263.. Test accuracy: 0.887
# Epoch 8/20.. Train loss: 0.283.. Test loss: 0.272.. Test accuracy: 0.882
# Epoch 8/20.. Train loss: 0.280.. Test loss: 0.268.. Test accuracy: 0.886
# Epoch 9/20.. Train loss: 0.278.. Test loss: 0.326.. Test accuracy: 0.861
# Epoch 9/20.. Train loss: 0.290.. Test loss: 0.251.. Test accuracy: 0.896
# Epoch 9/20.. Train loss: 0.284.. Test loss: 0.270.. Test accuracy: 0.885
# Epoch 9/20.. Train loss: 0.290.. Test loss: 0.257.. Test accuracy: 0.890
# Epoch 9/20.. Train loss: 0.291.. Test loss: 0.254.. Test accuracy: 0.895
# Epoch 10/20.. Train loss: 0.284.. Test loss: 0.278.. Test accuracy: 0.884
# Epoch 10/20.. Train loss: 0.263.. Test loss: 0.270.. Test accuracy: 0.884
# Epoch 10/20.. Train loss: 0.285.. Test loss: 0.253.. Test accuracy: 0.895
# Epoch 10/20.. Train loss: 0.280.. Test loss: 0.282.. Test accuracy: 0.880
# Epoch 10/20.. Train loss: 0.295.. Test loss: 0.316.. Test accuracy: 0.863
# Epoch 11/20.. Train loss: 0.306.. Test loss: 0.292.. Test accuracy: 0.872
# Epoch 11/20.. Train loss: 0.283.. Test loss: 0.273.. Test accuracy: 0.887
# Epoch 11/20.. Train loss: 0.268.. Test loss: 0.257.. Test accuracy: 0.892
# Epoch 11/20.. Train loss: 0.247.. Test loss: 0.261.. Test accuracy: 0.890
# Epoch 11/20.. Train loss: 0.264.. Test loss: 0.260.. Test accuracy: 0.890
# Epoch 12/20.. Train loss: 0.308.. Test loss: 0.254.. Test accuracy: 0.894
# Epoch 12/20.. Train loss: 0.270.. Test loss: 0.253.. Test accuracy: 0.896
# Epoch 12/20.. Train loss: 0.254.. Test loss: 0.275.. Test accuracy: 0.882
# Epoch 12/20.. Train loss: 0.276.. Test loss: 0.257.. Test accuracy: 0.892
# Epoch 12/20.. Train loss: 0.277.. Test loss: 0.260.. Test accuracy: 0.892
# Epoch 13/20.. Train loss: 0.273.. Test loss: 0.284.. Test accuracy: 0.876
# Epoch 13/20.. Train loss: 0.276.. Test loss: 0.261.. Test accuracy: 0.890
# Epoch 13/20.. Train loss: 0.261.. Test loss: 0.235.. Test accuracy: 0.903
# Epoch 13/20.. Train loss: 0.269.. Test loss: 0.239.. Test accuracy: 0.899
# Epoch 13/20.. Train loss: 0.264.. Test loss: 0.253.. Test accuracy: 0.897
# Epoch 13/20.. Train loss: 0.280.. Test loss: 0.312.. Test accuracy: 0.863
# Epoch 14/20.. Train loss: 0.244.. Test loss: 0.237.. Test accuracy: 0.899
# Epoch 14/20.. Train loss: 0.248.. Test loss: 0.235.. Test accuracy: 0.903
# Epoch 14/20.. Train loss: 0.246.. Test loss: 0.224.. Test accuracy: 0.905
# Epoch 14/20.. Train loss: 0.255.. Test loss: 0.228.. Test accuracy: 0.906
# Epoch 14/20.. Train loss: 0.290.. Test loss: 0.245.. Test accuracy: 0.900
# Epoch 15/20.. Train loss: 0.245.. Test loss: 0.260.. Test accuracy: 0.889
# Epoch 15/20.. Train loss: 0.260.. Test loss: 0.241.. Test accuracy: 0.898
# Epoch 15/20.. Train loss: 0.252.. Test loss: 0.239.. Test accuracy: 0.900
# Epoch 15/20.. Train loss: 0.243.. Test loss: 0.253.. Test accuracy: 0.894
# Epoch 15/20.. Train loss: 0.273.. Test loss: 0.240.. Test accuracy: 0.900
# Epoch 16/20.. Train loss: 0.248.. Test loss: 0.250.. Test accuracy: 0.895
# Epoch 16/20.. Train loss: 0.262.. Test loss: 0.227.. Test accuracy: 0.904
# Epoch 16/20.. Train loss: 0.275.. Test loss: 0.249.. Test accuracy: 0.899
# Epoch 16/20.. Train loss: 0.261.. Test loss: 0.233.. Test accuracy: 0.906
# Epoch 16/20.. Train loss: 0.240.. Test loss: 0.226.. Test accuracy: 0.906
# Epoch 17/20.. Train loss: 0.274.. Test loss: 0.240.. Test accuracy: 0.900
# Epoch 17/20.. Train loss: 0.252.. Test loss: 0.218.. Test accuracy: 0.910
# Epoch 17/20.. Train loss: 0.254.. Test loss: 0.221.. Test accuracy: 0.905
# Epoch 17/20.. Train loss: 0.222.. Test loss: 0.242.. Test accuracy: 0.896
# Epoch 17/20.. Train loss: 0.232.. Test loss: 0.210.. Test accuracy: 0.912
# Epoch 18/20.. Train loss: 0.234.. Test loss: 0.220.. Test accuracy: 0.908
# Epoch 18/20.. Train loss: 0.230.. Test loss: 0.229.. Test accuracy: 0.905
# Epoch 18/20.. Train loss: 0.242.. Test loss: 0.223.. Test accuracy: 0.907
# Epoch 18/20.. Train loss: 0.221.. Test loss: 0.222.. Test accuracy: 0.908
# Epoch 18/20.. Train loss: 0.246.. Test loss: 0.244.. Test accuracy: 0.900
# Epoch 19/20.. Train loss: 0.229.. Test loss: 0.213.. Test accuracy: 0.913
# Epoch 19/20.. Train loss: 0.241.. Test loss: 0.224.. Test accuracy: 0.913
# Epoch 19/20.. Train loss: 0.238.. Test loss: 0.224.. Test accuracy: 0.908
# Epoch 19/20.. Train loss: 0.253.. Test loss: 0.233.. Test accuracy: 0.908
# Epoch 19/20.. Train loss: 0.230.. Test loss: 0.218.. Test accuracy: 0.907
# Epoch 19/20.. Train loss: 0.222.. Test loss: 0.208.. Test accuracy: 0.917
# Epoch 20/20.. Train loss: 0.240.. Test loss: 0.239.. Test accuracy: 0.899
# Epoch 20/20.. Train loss: 0.250.. Test loss: 0.225.. Test accuracy: 0.907
# Epoch 20/20.. Train loss: 0.224.. Test loss: 0.205.. Test accuracy: 0.916
# Epoch 20/20.. Train loss: 0.222.. Test loss: 0.217.. Test accuracy: 0.909
# Epoch 20/20.. Train loss: 0.240.. Test loss: 0.225.. Test accuracy: 0.905

# %%
plt.plot(train_losses,label='Traning Loss')
plt.plot(test_losses,label='Validation Loss')

plt.legend(frameon=False)
plt.show()

# %%
from facenet_pytorch import MTCNN
import torch
import numpy as np
import cv2
from PIL import Image,ImageDraw
from IPython import display
import imutils

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

#Load Model
model=torch.load('classifymodel.pth')
model.eval()
# Out:
# cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %%
mtcnn=MTCNN(keep_all=True, device=device)
transform=transforms.Compose([transforms.Resize((80,80)),transforms.ToTensor(),])

classes=['female','male']
check_transforms=transforms.Compose([transforms.Resize((80,80)),transforms.ToTensor(),
                                     transforms.ToPILImage(),])

# %%
def predict_image(image):
    image_tensor=transform(image).float()
    image_tensor=image_tensor.unsqueeze_(0)
    input= Variable(image_tensor).to(device)
    output=model(input)
    
    index=output.data.cpu().numpy().argmax()
    return index

# %%
"""
cap=cv2.VideoCapture(0)


frame_width = int(cap.get(3)) 
frame_height = int(cap.get(4)) 
size = (frame_width, frame_height)
#result = cv2.VideoWriter('output.avi',  cv2.VideoWriter_fourcc(*'MJPG'), 20,size )


while True:
    ret,image=cap.read()
    frame=image.copy()
    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)

    boxes,_=mtcnn.detect(frame)

    color=(0,255,0)
    if boxes is not None:
        for box in boxes:
            startX,endX=int(box[0])-1,int(box[2])+1
            startY,endY=int(box[1])-1,int(box[3])+1
            cv2.rectangle(image,(box[0],box[1]),(box[2],box[3]) , color, 2)
            face = frame[startY:endY, startX:endX]
            img = Image.fromarray(face)
            img=check_transforms(img)
            index=predict_image(img)
            label=str(classes[index])
            color = (0, 255, 0)
            cv2.putText(image, label, (startX, startY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
            #result.write(image)
    cv2.imshow("frame",image)
    k=cv2.waitKey(1) & 0xFF
    if k == ord("q"):
        print("Escapehit, closing...")
        break
cap.release()
#result.release()
cv2.destroyAllWindows()

"""
# Out:
# '\ncap=cv2.VideoCapture(0)\n\n\nframe_width = int(cap.get(3)) \nframe_height = int(cap.get(4)) \nsize = (frame_width, frame_height)\n#result = cv2.VideoWriter(\'output.avi\',  cv2.VideoWriter_fourcc(*\'MJPG\'), 20,size )\n\n\nwhile True:\n    ret,image=cap.read()\n    frame=image.copy()\n    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)\n\n    boxes,_=mtcnn.detect(frame)\n\n    color=(0,255,0)\n    if boxes is not None:\n        for box in boxes:\n            startX,endX=int(box[0])-1,int(box[2])+1\n            startY,endY=int(box[1])-1,int(box[3])+1\n            cv2.rectangle(image,(box[0],box[1]),(box[2],box[3]) , color, 2)\n            face = frame[startY:endY, startX:endX]\n            img = Image.fromarray(face)\n            img=check_transforms(img)\n            index=predict_image(img)\n            label=str(classes[index])\n            color = (0, 255, 0)\n            cv2.putText(image, label, (startX, startY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)\n            #result.write(image)\n    cv2.imshow("frame",image)\n    k=cv2.waitKey(1) & 0xFF\n    if k == ord("q"):\n        print("Escapehit, closing...")\n        break\ncap.release()\n#result.release()\ncv2.destroyAllWindows()\n\n'

# %%
image=cv2.imread("Sample Images/Image1.jpg")
image=imutils.resize(image,width=600)
frame=image.copy()
frame=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)

boxes,_=mtcnn.detect(frame)

color=(0,255,0)
if boxes is not None:
    for box in boxes:
        startX,endX=int(box[0])-1,int(box[2])+1
        startY,endY=int(box[1])-1,int(box[3])+1
        cv2.rectangle(image,(box[0],box[1]),(box[2],box[3]) , color, 2)
        face = frame[startY:endY, startX:endX]
        img = Image.fromarray(face)
        img=check_transforms(img)
        index=predict_image(img)
        label=str(classes[index])
        color = (0, 255, 0)
        cv2.putText(image, label, (startX, startY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        #result.write(image)
cv2.imshow("image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
